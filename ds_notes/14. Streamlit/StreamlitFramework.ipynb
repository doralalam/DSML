# %% [markdown]
# #### Streamlit
#
# 1. Streamlit is an open-source app framework for Machine Learning and Data Science projects
#
# 2. Without using HTML and CSS, just by using Streamlit components, we can create beautiful web pages using Python scripts

# %%
## To install streamlit framework

! pip install streamlit

# %%
## To run the streamlit app, we must use the following command in the terminal

'''
streamlit run app.py
'''
# Out:
# '\nstreamlit run app.py\n'
