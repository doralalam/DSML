# %% [markdown]
# #### Streamlit
#
# 1. Streamlit is a web framework for Machine Learning and Data Science projects
#
# 2. Without using HTML and CSS, just by using Streamlit components, we can create beautiful web pages using Python scripts
