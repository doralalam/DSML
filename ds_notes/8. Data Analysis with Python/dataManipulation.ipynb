# %% [markdown]
# #### Data Manipulation and Analysis with Pandas

# %% [markdown]
# Data manipulation and analysis are key tasks in any data science or data analysis projects.
#
# Pandas provides wide range of functions to perform Data Manipulation and Analysis, making it easier to clean, transform, and extract insights from the data

# %%
import pandas as pd

# %%
df = pd.read_csv('Energy_Production_Dataset.csv')

## fetch the first 5 rows of the data
df.head(5)
# Out:
#          Date  Start_Hour  End_Hour Source  Day_of_Year Day_Name Month_Name  \
# 0  11/30/2025        21.0        22   Wind          334   Sunday   November
# 1  11/30/2025        18.0        19   Wind          334   Sunday   November
# 2  11/30/2025        16.0        17   Wind          334   Sunday   November
# 3  11/30/2025        23.0         0    NaN          334   Sunday   November
# 4  11/30/2025         6.0         7   Wind          334      NaN   November
#
#   Season  Production
# 0   Fall         NaN
# 1   Fall      3824.0
# 2   Fall      3824.0
# 3   Fall      6120.0
# 4   Fall      4387.0

# %%
## decribe the data
df.describe()
# Out:
#          Start_Hour      End_Hour   Day_of_Year    Production
# count  51863.000000  51864.000000  51864.000000  51862.000000
# mean      11.500106     11.500000    180.798415   6214.907022
# std        6.922278      6.922253    104.291387   3978.226203
# min        0.000000      0.000000      1.000000     58.000000
# 25%        5.500000      5.750000     91.000000   3111.000000
# 50%       12.000000     11.500000    181.000000   5372.000000
# 75%       17.500000     17.250000    271.000000   8500.750000
# max       23.000000     23.000000    366.000000  23446.000000

# %%
## To get the data types

df.dtypes
# Out:
# Date            object
# Start_Hour     float64
# End_Hour         int64
# Source          object
# Day_of_Year      int64
# Day_Name        object
# Month_Name      object
# Season          object
# Production     float64
# dtype: object

# %%
## Handling the missing values

df.isnull()

## True = Value is missing

## False = Value is present
# Out:
#         Date  Start_Hour  End_Hour  Source  Day_of_Year  Day_Name  Month_Name  \
# 0      False       False     False   False        False     False       False
# 1      False       False     False   False        False     False       False
# 2      False       False     False   False        False     False       False
# 3      False       False     False    True        False     False       False
# 4      False       False     False   False        False      True       False
# ...      ...         ...       ...     ...          ...       ...         ...
# 51859  False       False     False   False        False     False       False
# 51860  False       False     False   False        False     False       False
# 51861  False       False     False   False        False     False       False
# 51862  False       False     False   False        False     False       False
# 51863  False       False     False   False        False     False       False
#
#        Season  Production
# 0       False        True
# 1       False       False
# 2       False       False
# 3       False       False
# 4       False       False
# ...       ...         ...
# 51859   False       False
# 51860   False       False
# 51861   False       False
# 51862   False       False
# 51863   False       False
#
# [51864 rows x 9 columns]

# %%
df.isnull().any()

## By default axis=0, so it goes through the row index (Aggregates Columns)
## i.e., if all the rows in a column is False, then the result is False, else True
# Out:
# Date           False
# Start_Hour      True
# End_Hour       False
# Source          True
# Day_of_Year    False
# Day_Name        True
# Month_Name      True
# Season         False
# Production      True
# dtype: bool

# %%
## By setting axis=1, so it goes through the column index (Aggregates Rows)
## i.e., if all the columns values in a row is False, then the result is False, else True

df.isnull().any(axis=1)
# Out:
# 0         True
# 1        False
# 2        False
# 3         True
# 4         True
#          ...
# 51859    False
# 51860    False
# 51861    False
# 51862    False
# 51863    False
# Length: 51864, dtype: bool

# %%
## To get the number of rows that each attribute has a missing value

df.isnull().sum()
# Out:
# Date           0
# Start_Hour     1
# End_Hour       0
# Source         1
# Day_of_Year    0
# Day_Name       1
# Month_Name     1
# Season         0
# Production     2
# dtype: int64

# %%
df.head(5)
# Out:
#          Date  Start_Hour  End_Hour Source  Day_of_Year Day_Name Month_Name  \
# 0  11/30/2025        21.0        22   Wind          334   Sunday   November
# 1  11/30/2025        18.0        19   Wind          334   Sunday   November
# 2  11/30/2025        16.0        17   Wind          334   Sunday   November
# 3  11/30/2025        23.0         0    NaN          334   Sunday   November
# 4  11/30/2025         6.0         7   Wind          334      NaN   November
#
#   Season  Production
# 0   Fall         NaN
# 1   Fall      3824.0
# 2   Fall      3824.0
# 3   Fall      6120.0
# 4   Fall      4387.0

# %%
## To fill all the missing values (NaN) with 0
## In real-time, we usually fill the missing values with the mean of that column

df.fillna(0)
# Out:
#              Date  Start_Hour  End_Hour Source  Day_of_Year   Day_Name  \
# 0      11/30/2025        21.0        22   Wind          334     Sunday
# 1      11/30/2025        18.0        19   Wind          334     Sunday
# 2      11/30/2025        16.0        17   Wind          334     Sunday
# 3      11/30/2025        23.0         0      0          334     Sunday
# 4      11/30/2025         6.0         7   Wind          334          0
# ...           ...         ...       ...    ...          ...        ...
# 51859    1/1/2020         4.0         5   Wind            1  Wednesday
# 51860    1/1/2020        18.0        19   Wind            1  Wednesday
# 51861    1/1/2020         7.0         8   Wind            1  Wednesday
# 51862    1/1/2020        14.0        15  Solar            1  Wednesday
# 51863    1/1/2020        13.0        14  Solar            1  Wednesday
#
#       Month_Name  Season  Production
# 0       November    Fall         0.0
# 1       November    Fall      3824.0
# 2       November    Fall      3824.0
# 3       November    Fall      6120.0
# 4       November    Fall      4387.0
# ...          ...     ...         ...
# 51859    January  Winter      2708.0
# 51860    January  Winter      1077.0
# 51861    January  Winter      2077.0
# 51862    January  Winter      1783.0
# 51863    January  Winter      2179.0
#
# [51864 rows x 9 columns]

# %%
## Copy the filled DataFrame

new_df = df.fillna(0)
new_df
# Out:
#              Date  Start_Hour  End_Hour Source  Day_of_Year   Day_Name  \
# 0      11/30/2025        21.0        22   Wind          334     Sunday
# 1      11/30/2025        18.0        19   Wind          334     Sunday
# 2      11/30/2025        16.0        17   Wind          334     Sunday
# 3      11/30/2025        23.0         0      0          334     Sunday
# 4      11/30/2025         6.0         7   Wind          334          0
# ...           ...         ...       ...    ...          ...        ...
# 51859    1/1/2020         4.0         5   Wind            1  Wednesday
# 51860    1/1/2020        18.0        19   Wind            1  Wednesday
# 51861    1/1/2020         7.0         8   Wind            1  Wednesday
# 51862    1/1/2020        14.0        15  Solar            1  Wednesday
# 51863    1/1/2020        13.0        14  Solar            1  Wednesday
#
#       Month_Name  Season  Production
# 0       November    Fall         0.0
# 1       November    Fall      3824.0
# 2       November    Fall      3824.0
# 3       November    Fall      6120.0
# 4       November    Fall      4387.0
# ...          ...     ...         ...
# 51859    January  Winter      2708.0
# 51860    January  Winter      1077.0
# 51861    January  Winter      2077.0
# 51862    January  Winter      1783.0
# 51863    January  Winter      2179.0
#
# [51864 rows x 9 columns]

# %%
df.describe()
# Out:
#          Start_Hour      End_Hour   Day_of_Year    Production
# count  51863.000000  51864.000000  51864.000000  51862.000000
# mean      11.500106     11.500000    180.798415   6214.907022
# std        6.922278      6.922253    104.291387   3978.226203
# min        0.000000      0.000000      1.000000     58.000000
# 25%        5.500000      5.750000     91.000000   3111.000000
# 50%       12.000000     11.500000    181.000000   5372.000000
# 75%       17.500000     17.250000    271.000000   8500.750000
# max       23.000000     23.000000    366.000000  23446.000000

# %%
## To fill the missing values with the mean of the respective column

df['New_Production'] = df['Production'].fillna(df['Production'].mean())
df.head(5)
## In this, we can clearly see that, Production value for the 0th row has been replaced with mean of the production and stored in New_Production column
# Out:
#          Date  Start_Hour  End_Hour Source  Day_of_Year Day_Name Month_Name  \
# 0  11/30/2025        21.0        22   Wind          334   Sunday   November
# 1  11/30/2025        18.0        19   Wind          334   Sunday   November
# 2  11/30/2025        16.0        17   Wind          334   Sunday   November
# 3  11/30/2025        23.0         0    NaN          334   Sunday   November
# 4  11/30/2025         6.0         7   Wind          334      NaN   November
#
#   Season  Production  New_Production
# 0   Fall         NaN     6214.907022
# 1   Fall      3824.0     3824.000000
# 2   Fall      3824.0     3824.000000
# 3   Fall      6120.0     6120.000000
# 4   Fall      4387.0     4387.000000

# %%
df.isnull().any()

## Here, New_Production column is False, since all the missing values were replaced with mean of Production column
# Out:
# Date              False
# Start_Hour         True
# End_Hour          False
# Source             True
# Day_of_Year       False
# Day_Name           True
# Month_Name         True
# Season            False
# Production         True
# New_Production    False
# dtype: bool

# %% [markdown]
# #### To Rename the columns and perform Data Type conversions

# %%
df.dtypes
# Out:
# Date               object
# Start_Hour        float64
# End_Hour            int64
# Source             object
# Day_of_Year         int64
# Day_Name           object
# Month_Name         object
# Season             object
# Production        float64
# New_Production    float64
# dtype: object

# %%
## Renaming the columns

df = df.rename(columns={'New_Production':'Updated_Production'})
df.head(5)
# Out:
#          Date  Start_Hour  End_Hour Source  Day_of_Year Day_Name Month_Name  \
# 0  11/30/2025        21.0        22   Wind          334   Sunday   November
# 1  11/30/2025        18.0        19   Wind          334   Sunday   November
# 2  11/30/2025        16.0        17   Wind          334   Sunday   November
# 3  11/30/2025        23.0         0    NaN          334   Sunday   November
# 4  11/30/2025         6.0         7   Wind          334      NaN   November
#
#   Season  Production  Updated_Production
# 0   Fall         NaN         6214.907022
# 1   Fall      3824.0         3824.000000
# 2   Fall      3824.0         3824.000000
# 3   Fall      6120.0         6120.000000
# 4   Fall      4387.0         4387.000000

# %%
## To change the data type of Start_Hour column

df['New_Start_Hour'] = df['Start_Hour'].astype(int)
df.head(5)

## Here the error is because of the missing value in Start_Hour column
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[73], line 3
#       1 ## To change the data type of Start_Hour column
# ----> 3 df['New_Start_Hour'] = df['Start_Hour'].astype(int)
#       4 df.head(5)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/internals/blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:101, in _astype_nansafe(arr, dtype, copy, skipna)
#      96     return lib.ensure_string_array(
#      97         arr, skipna=skipna, convert_na_value=False
#      98     ).reshape(shape)
#     100 elif np.issubdtype(arr.dtype, np.floating) and dtype.kind in "iu":
# --> 101     return _astype_float_to_int_nansafe(arr, dtype, copy)
#     103 elif arr.dtype == object:
#     104     # if we have a datetime/timedelta array of objects
#     105     # then coerce to datetime64[ns] and use DatetimeArray.astype
#     107     if lib.is_np_dtype(dtype, "M"):
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:145, in _astype_float_to_int_nansafe(values, dtype, copy)
#     141 """
#     142 astype with a check preventing converting NaN to an meaningless integer value.
#     143 """
#     144 if not np.isfinite(values).all():
# --> 145     raise IntCastingNaNError(
#     146         "Cannot convert non-finite values (NA or inf) to integer"
#     147     )
#     148 if dtype.kind == "u":
#     149     # GH#45151
#     150     if not (values >= 0).all():
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %%
df.isnull().any()

## True value in Start_Hour indicates that it is having missing values
# Out:
# Date                  False
# Start_Hour             True
# End_Hour              False
# Source                 True
# Day_of_Year           False
# Day_Name               True
# Month_Name             True
# Season                False
# Production             True
# Updated_Production    False
# New_Start_Hour        False
# dtype: bool

# %%
## To change the data type after replacing the missing value with the mean of that column

df['New_Start_Hour'] = df['Start_Hour'].fillna(df['Start_Hour'].mean()).astype(int)
df.head(5)
# Out:
#          Date  Start_Hour  End_Hour Source  Day_of_Year Day_Name Month_Name  \
# 0  11/30/2025        21.0        22   Wind          334   Sunday   November
# 1  11/30/2025        18.0        19   Wind          334   Sunday   November
# 2  11/30/2025        16.0        17   Wind          334   Sunday   November
# 3  11/30/2025        23.0         0    NaN          334   Sunday   November
# 4  11/30/2025         6.0         7   Wind          334      NaN   November
#
#   Season  Production  Updated_Production  New_Start_Hour
# 0   Fall         NaN         6214.907022              21
# 1   Fall      3824.0         3824.000000              18
# 2   Fall      3824.0         3824.000000              16
# 3   Fall      6120.0         6120.000000              23
# 4   Fall      4387.0         4387.000000               6

# %%
df.isnull().any()

## Here, Start_Hour = True, indicates missing values
## New_Strat_Hour = False, indicates no missing values becuase we have replaced them with mean values
# Out:
# Date                  False
# Start_Hour             True
# End_Hour              False
# Source                 True
# Day_of_Year           False
# Day_Name               True
# Month_Name             True
# Season                False
# Production             True
# Updated_Production    False
# New_Start_Hour        False
# dtype: bool

# %%
df.dtypes

## Here Start_Hour is of float64 type
## Whereas New_Start_Hour is of int64 type
# Out:
# Date                   object
# Start_Hour            float64
# End_Hour                int64
# Source                 object
# Day_of_Year             int64
# Day_Name               object
# Month_Name             object
# Season                 object
# Production            float64
# Updated_Production    float64
# New_Start_Hour          int64
# dtype: object

# %%
## To apply changes to the values in all the rows for a particular column
## For example, to increase the production to 2X

df['2X_Production'] = df['Updated_Production'].apply(lambda x:x*2)
df.head(5)

## Here, we used lambda function i.e., custom or anonymous function.
## Likewise, we can also use any function as per our requirement by passing the parameters
# Out:
#          Date  Start_Hour  End_Hour Source  Day_of_Year Day_Name Month_Name  \
# 0  11/30/2025        21.0        22   Wind          334   Sunday   November
# 1  11/30/2025        18.0        19   Wind          334   Sunday   November
# 2  11/30/2025        16.0        17   Wind          334   Sunday   November
# 3  11/30/2025        23.0         0    NaN          334   Sunday   November
# 4  11/30/2025         6.0         7   Wind          334      NaN   November
#
#   Season  Production  Updated_Production  New_Start_Hour  2X_Production
# 0   Fall         NaN         6214.907022              21   12429.814045
# 1   Fall      3824.0         3824.000000              18    7648.000000
# 2   Fall      3824.0         3824.000000              16    7648.000000
# 3   Fall      6120.0         6120.000000              23   12240.000000
# 4   Fall      4387.0         4387.000000               6    8774.000000

# %%
## Custom defined function for 3X Production

def Production3(val):
    return val*3

# %%
## To increase production to 3X using the function object

df['3X_Production'] = df['Production'].apply(Production3)
df.head(5)
# Out:
#          Date  Start_Hour  End_Hour Source  Day_of_Year Day_Name Month_Name  \
# 0  11/30/2025        21.0        22   Wind          334   Sunday   November
# 1  11/30/2025        18.0        19   Wind          334   Sunday   November
# 2  11/30/2025        16.0        17   Wind          334   Sunday   November
# 3  11/30/2025        23.0         0    NaN          334   Sunday   November
# 4  11/30/2025         6.0         7   Wind          334      NaN   November
#
#   Season  Production  Updated_Production  New_Start_Hour  2X_Production  \
# 0   Fall         NaN         6214.907022              21   12429.814045
# 1   Fall      3824.0         3824.000000              18    7648.000000
# 2   Fall      3824.0         3824.000000              16    7648.000000
# 3   Fall      6120.0         6120.000000              23   12240.000000
# 4   Fall      4387.0         4387.000000               6    8774.000000
#
#    3X_Production
# 0            NaN
# 1        11472.0
# 2        11472.0
# 3        18360.0
# 4        13161.0

# %% [markdown]
# #### Data Aggregating and Grouping

# %%
## To calculate the monthly Production

grouped_sum = df.groupby('Month_Name')['Production'].sum()
grouped_sum
# Out:
# Month_Name
# April        27277879.0
# August       21897618.0
# December     27395733.0
# February     31792273.0
# January      30851764.0
# July         23352391.0
# June         19813461.0
# March        31893888.0
# May          25914666.0
# November     29782797.0
# October      29499405.0
# September    22838624.0
# Name: Production, dtype: float64

# %%
## To calculate the monthly production with days in a week

weekday_sum = df.groupby(['Month_Name', 'Day_Name'])['Production'].sum()
weekday_sum
# Out:
# Month_Name  Day_Name
# April       Friday       3714010.0
#             Monday       3830308.0
#             Saturday     4185430.0
#             Sunday       3505450.0
#             Thursday     3756332.0
#                            ...
# September   Saturday     2797551.0
#             Sunday       2843334.0
#             Thursday     3376758.0
#             Tuesday      3332104.0
#             Wednesday    3489874.0
# Name: Production, Length: 84, dtype: float64

# %%
## To calculate the mean of the monthly production with days in a week

weekday_mean = df.groupby(['Month_Name', 'Day_Name'])['Production'].mean()
weekday_mean
# Out:
# Month_Name  Day_Name
# April       Friday       5951.939103
#             Monday       6383.846667
#             Saturday     6707.419872
#             Sunday       5842.416667
#             Thursday     6019.762821
#                             ...
# September   Saturday     4662.585000
#             Sunday       4738.890000
#             Thursday     5411.471154
#             Tuesday      5339.910256
#             Wednesday    5592.746795
# Name: Production, Length: 84, dtype: float64

# %%
## Aggregate multiple functions

grouped_agg = df.groupby('Month_Name')['Production'].aggregate(['sum', 'mean', 'count'])
grouped_agg
# Out:
#                    sum         mean  count
# Month_Name
# April       27277879.0  6314.323843   4320
# August      21897618.0  4905.380376   4464
# December    27395733.0  7364.444355   3720
# February    31792273.0  7792.223775   4080
# January     30851764.0  6911.237455   4464
# July        23352391.0  5231.270385   4464
# June        19813461.0  4586.449306   4320
# March       31893888.0  7154.304172   4458
# May         25914666.0  5805.256720   4464
# November    29782797.0  6898.956915   4317
# October     29499405.0  6599.419463   4470
# September   22838624.0  5286.718519   4320

# %% [markdown]
# #### Merging and Joining DataFrames

# %%
## Creating 2 sample DataFrames
df1 = pd.DataFrame({'Key':['A', 'B', 'C'], 'Value1':[1,2,3]})
df2 = pd.DataFrame({'Key': ['A', 'B', 'D'], 'Value2': [1,2,4]})

# %%
df1
# Out:
#   Key  Value1
# 0   A       1
# 1   B       2
# 2   C       3

# %%
df2
# Out:
#   Key  Value2
# 0   A       1
# 1   B       2
# 2   D       4

# %%
## To perform merge operations

pd.merge(df1,df2, on='Key', how = 'inner')
## It is like Intersection operation in sets
# Out:
#   Key  Value1  Value2
# 0   A       1       1
# 1   B       2       2

# %%
pd.merge(df1, df2, on='Key', how='outer')
## It is like union operation in sets
# Out:
#   Key  Value1  Value2
# 0   A     1.0     1.0
# 1   B     2.0     2.0
# 2   C     3.0     NaN
# 3   D     NaN     4.0

# %%
pd.merge(df1, df2, on='Key', how='left')
## left outer join i.e., all the elements from A and only matched elements from B
# Out:
#   Key  Value1  Value2
# 0   A       1     1.0
# 1   B       2     2.0
# 2   C       3     NaN

# %%
pd.merge(df1, df2, on='Key', how = 'right')
## right outer join i.e., all the elements from B and only matched elements from A
# Out:
#   Key  Value1  Value2
# 0   A     1.0       1
# 1   B     2.0       2
# 2   D     NaN       4
